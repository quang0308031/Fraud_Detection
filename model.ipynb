# %%
import tensorflow as tf

# %%
from Model.TH_LSTM import TH_LSTM

# %%
t = TH_LSTM(50, 10, 20)

# %%
tf.__version__
# Out:
# '2.14.0'

# %%
from Model.processing.preprocessing import data_generator

# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:\\Users\\Admin\\Downloads\\creditcard.csv')

# %%
data_generator(data, 50, 31)
# Out:
# (<tf.Tensor: shape=(284758, 50, 30), dtype=float32, numpy=
#  array([[[ 0.0000000e+00, -1.3598071e+00, -7.2781175e-02, ...,
#            1.3355838e-01, -2.1053053e-02,  1.4962000e+02],
#          [ 0.0000000e+00,  1.1918571e+00,  2.6615071e-01, ...,
#           -8.9830989e-03,  1.4724169e-02,  2.6900001e+00],
#          [ 1.0000000e+00, -1.3583541e+00, -1.3401631e+00, ...,
#           -5.5352796e-02, -5.9751842e-02,  3.7866000e+02],
#          ...,
#          [ 3.4000000e+01,  2.0168589e-01,  4.9748322e-01, ...,
#            1.4275725e-01,  2.1923761e-01,  9.9899998e+00],
#          [ 3.5000000e+01,  1.3863970e+00, -7.9420948e-01, ...,
#            5.3133187e-04,  1.9910622e-02,  3.0900000e+01],
#          [ 3.5000000e+01, -1.0632356e+00,  1.4181906e+00, ...,
#            1.1875364e-01, -8.9562982e-03,  2.0219999e+01]],
#
#         [[ 0.0000000e+00,  1.1918571e+00,  2.6615071e-01, ...,
#           -8.9830989e-03,  1.4724169e-02,  2.6900001e+00],
# ...
